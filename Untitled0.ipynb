# %% [markdown]
# <a href="https://colab.research.google.com/github/LachiqHamza/LachiqHamza/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
https://github.com/aissam-out/Cours-ML-DL.git
# Out:
#   File "<ipython-input-1-2c1be0edf834>", line 1
#     https://github.com/aissam-out/Cours-ML-DL.git
#           ^
# SyntaxError: invalid syntax
